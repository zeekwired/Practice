# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
# Load data 
school_df = pd.read_csv('School_Details.csv')
# Make sure it loaded correctly
school_df.head(2)
# Out:
#   DistrictName EstablishmentCode  \
# 0         East             S0169
# 1         East             S0099
#
#                                    EstablishmentName   BRCName  \
# 0               BUDANG GOVERNMENT PRIMARY SCHOOL (E)  Duga Brc
# 1  CENTRAL PENDAM GOVERNMENT SENIOR SECONDARY SCHOOL  Duga Brc
#
#                                              CRCName SchoolLevel  \
# 0  Central Pendam Government Senior Secondary School          PS
# 1  Central Pendam Government Senior Secondary School         SSS
#
#   ManagementName LocalityHabitation SubdivisionName ConstituencyName  ...  \
# 0    State Govt.             BUDANG         Gangtok          Rhenock  ...
# 1    State Govt.     CENTRAL PENDAM         Gangtok      West Pandam  ...
#
#   EstablishedDate DistrictHQDistance (in Km) CRCDistance (in Km)  \
# 0           28126                       58.0                 8.0
# 1           15342                       50.0                 0.0
#
#   BACDistance (in Km) IsRecognized RecognizedBy ContactPersonName LowestClass  \
# 0                16.0   Recognized         HRDD               NaN     Class 1
# 1                 6.0   Recognized         HRDD               NaN     Class 1
#
#   HighestClass BoardName
# 0      Class 5       NaN
# 1     Class 12  C.B.S.E.
#
# [2 rows x 30 columns]

# %%
# create sqlite engine for a database called schools
engine= create_engine('sqlite:///schools.db', echo=True)
# create connection to engine
conn = engine.connect()

# %%
# add the dataframe as a table in sqlite
sqlite_table = "school_details"
school_df.to_sql(sqlite_table, conn, if_exists='fail')
# Out:
# 2023-02-19 13:16:57,545 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("school_details")
# 2023-02-19 13:16:57,546 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-02-19 13:16:57,546 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("school_details")
# 2023-02-19 13:16:57,547 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2023-02-19 13:16:57,549 INFO sqlalchemy.engine.Engine
# CREATE TABLE school_details (
# 	"index" BIGINT,
# 	"DistrictName" TEXT,
# 	"EstablishmentCode" TEXT,
# 	"EstablishmentName" TEXT,
# 	"BRCName" TEXT,
# 	"CRCName" TEXT,
# 	"SchoolLevel" TEXT,
# 	"ManagementName" TEXT,
# 	"LocalityHabitation" TEXT,
# 	"SubdivisionName" TEXT,
# 	"ConstituencyName" TEXT,
# 	"RevenueBlockName" TEXT,
# 	"CivicBodyName" TEXT,
# 	"WardName" TEXT,
# 	"PostOfficeName" TEXT,
# 	"PhoneNo" TEXT,
# 	"FaxNo" TEXT,
# 	"EmailID" TEXT,
# 	"Website" TEXT,
# 	"LocatedInRuralOrUrban" TEXT,
# 	"DiseCode" TEXT,
# 	"EstablishedDate" TEXT,
# 	"DistrictHQDistance (in Km)" FLOAT,
# 	"CRCDistance (in Km)" FLOAT,
# 	"BACDistance (in Km)" FLOAT,
# 	"IsRecognized" TEXT,
# 	"RecognizedBy" TEXT,
# 	"ContactPersonName" FLOAT,
# 	"LowestClass" TEXT,
# 	"HighestClass" TEXT,
# 	"BoardName" TEXT
# )
#
#
# 2023-02-19 13:16:57,550 INFO sqlalchemy.engine.Engine [no key 0.00073s] ()
# 2023-02-19 13:16:57,554 INFO sqlalchemy.engine.Engine COMMIT
# 2023-02-19 13:16:57,555 INFO sqlalchemy.engine.Engine CREATE INDEX ix_school_details_index ON school_details ("index")
# 2023-02-19 13:16:57,556 INFO sqlalchemy.engine.Engine [no key 0.00075s] ()
# 2023-02-19 13:16:57,559 INFO sqlalchemy.engine.Engine COMMIT
# 2023-02-19 13:16:57,579 INFO sqlalchemy.engine.Engine INSERT INTO school_details ("index", "DistrictName", "EstablishmentCode", "EstablishmentName", "BRCName", "CRCName", "SchoolLevel", "ManagementName", "LocalityHabitation", "SubdivisionName", "ConstituencyName", "RevenueBlockName", "CivicBodyName", "WardName", "PostOfficeName", "PhoneNo", "FaxNo", "EmailID", "Website", "LocatedInRuralOrUrban", "DiseCode", "EstablishedDate", "DistrictHQDistance (in Km)", "CRCDistance (in Km)", "BACDistance (in Km)", "IsRecognized", "RecognizedBy", "ContactPersonName", "LowestClass", "HighestClass", "BoardName") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2023-02-19 13:16:57,581 INFO sqlalchemy.engine.Engine [generated in 0.01223s] ((0, 'East', 'S0169', 'BUDANG GOVERNMENT PRIMARY SCHOOL (E)', 'Duga Brc', 'Central Pendam Government Senior Secondary School', 'PS', 'State Govt.', 'BUDANG', 'Gangtok', 'Rhenock', 'Central Pendam', 'Central Pendam', 'Sajong', 'Upper Pendam', None, None, None, None, 'Urban Area', None, '28126', 58.0, 8.0, 16.0, 'Recognized', 'HRDD', None, 'Class 1', 'Class 5', None), (1, 'East', 'S0099', 'CENTRAL PENDAM GOVERNMENT SENIOR SECONDARY SCHOOL', 'Duga Brc', 'Central Pendam Government Senior Secondary School', 'SSS', 'State Govt.', 'CENTRAL PENDAM', 'Gangtok', 'West Pandam', 'Central Pendam', 'Central Pendam', 'Karmithang', 'Upper Pendam', '3592263812', None, None, None, 'Urban Area', '800401', '15342', 50.0, 0.0, 6.0, 'Recognized', 'HRDD', None, 'Class 1', 'Class 12', 'C.B.S.E.'), (2, 'East', 'S0848', 'CENTRAL POINT ACADEMY, CENTRAL PENDAM', 'Duga Brc', 'Central Pendam Government Senior Secondary School', 'SS', 'Private (Unaided)', 'UPPER BHURUNG CENTRAL PENDAM', 'Gangtok', 'West Pandam', 'Central Pendam', 'Central Pendam', 'Burung', 'Upper Pendam', '03592263809/263960', None, 'ksu_5162@yahoo.com', 'www.facebook.com/khanalkeshav (Group-CPA)', 'Urban Area', None, '37257.38680555556', 49.0, 1.5, 6.0, 'Recognized', 'HRDD, GOVT. OF SIKKIM', None, 'Class 1', 'Class 10', 'C.B.S.E.'), (3, 'East', 'S0190', 'CHEURIBOTEY GOVERNMENT JUNIOR HIGH SCHOOL (E)', 'Duga Brc', 'Central Pendam Government Senior Secondary School', 'JHS', 'State Govt.', 'CHEURIBOTEY', 'Gangtok', 'West Pandam', 'Central Pendam', 'Central Pendam', 'Cheuribotey', 'Duga', None, None, None, None, 'Urban Area', None, '28856', 60.0, 6.0, 6.0, 'Recognized', 'State Govt.', None, 'Class 1', 'Class 8', None), (4, 'East', 'S0111', 'DUGA GOVERNMENT SECONDARY SCHOOL', 'Duga Brc', 'Central Pendam Government Senior Secondary School', 'SS', 'State Govt.', 'DUGA', 'Gangtok', 'West Pandam', 'Central Pendam', 'Central Pendam', 'Duga', 'Duga', '9832082915', None, 'dugaschool@gmail.com', None, 'Urban Area', None, '1828', 52.0, 0.0, 0.5, 'Recognized', 'c.b.s.e.', None, 'Class 1', 'Class 10', 'C.B.S.E.'), (5, 'East', 'S0856', 'EASWARAMMA SAI GURUKOOL ACCADEMY', 'Duga Brc', 'Central Pendam Government Senior Secondary School', 'PS', 'Private (Unaided)', 'RALUNG', 'Gangtok', 'West Pandam', 'Central Pendam', 'West Pendam', 'Ralang', 'West Pendam', '9733056624', None, None, None, 'Urban Area', None, '40179.66805555556', 0.0, 0.2, 0.2, 'Recognized', None, None, 'Class 1', 'Class 5', None), (6, 'East', 'S0870', 'ETERNAL ENGLISH SCHOOL, WEST PENDAM', 'Duga Brc', 'Central Pendam Government Senior Secondary School', 'PS', 'Private (Unaided)', 'SAKHU WEST PENDAM', 'Gangtok', 'West Pandam', 'West Pendam', 'West Pendam', 'Sakhu', 'Sakhu Busty', '9734190544', None, None, None, 'Urban Area', None, '37300.66805555556', 42.0, 3.0, 4.0, 'Recognized', 'HRDD OF SIKKIM', None, 'Class 1', 'Class 5', None), (7, 'East', 'S0157', 'KHANI GOAN GOVERNMENT PRIMARY SCHOOL', 'Duga Brc', 'Central Pendam Government Senior Secondary School', 'PS', 'State Govt.', 'WEST PENDAM', 'Gangtok', 'West Pandam', 'West Pendam', 'West Pendam', 'Khanigaon', 'West Pendam', '9832470263', None, None, None, 'Urban Area', '801801', '29587', 45.0, 5.0, 4.0, 'Recognized', 'State Govt.', None, 'Class 1', 'Class 5', 'C.B.S.E.')  ... displaying 10 of 1249 total bound parameter sets ...  (1247, 'West', 'S0340', 'TINGTING GAON GOVERNMENT PRIMARY SCHOOL', 'Yuksom Brc', 'Yuksom Government Secondary School', 'PS', 'State Govt.', 'TING TING GAON', 'Gyalshing', 'Yoksam-Tashiding', 'Yoksam', 'Yuksom', 'Tingting', 'Yuksom', '9593377402', None, None, None, 'Urban Area', '100282', '29587', 36.0, 3.0, 6.0, 'Recognized', 'STATE GOVERNMENT', None, 'Class 1', 'Class 5', None), (1248, 'West', 'S0542', 'TSONG GOVERNMENT PRIMARY SCHOOL', 'Yuksom Brc', 'Yuksom Government Secondary School', 'PS', 'State Govt.', 'TSONG', 'Gyalshing', 'Yoksam-Tashiding', 'Yoksam', 'Yuksom', 'Yoksam', 'Yuksom', No ...
# 2023-02-19 13:16:57,591 INFO sqlalchemy.engine.Engine COMMIT
# 1249

# %%
# Write your SQL query in this string
sql = """
SELECT DistrictName
FROM school_details
Limit 2;
"""
# Read the sql query into pandas to view the results
pd.read_sql_query(sql, engine)
# Out:
# 2023-02-19 13:19:03,041 INFO sqlalchemy.engine.Engine
# SELECT DistrictName
# FROM school_details
# Limit 2;
#
# 2023-02-19 13:19:03,042 INFO sqlalchemy.engine.Engine [raw sql] ()
#   DistrictName
# 0         East
# 1         East

# %% [markdown]
# # SELECT and FROM

# %%
# Write the Sql query
sql = """SELECT SchoolLevel, ManagementName
FROM school_details
Limit 2;
"""
# Read the sql query into pandas to view the results
pd.read_sql_query(sql, engine)
# Out:
# 2023-02-19 13:25:08,490 INFO sqlalchemy.engine.Engine SELECT SchoolLevel, ManagementName
# FROM school_details
# Limit 2;
#
# 2023-02-19 13:25:08,490 INFO sqlalchemy.engine.Engine [raw sql] ()
#   SchoolLevel ManagementName
# 0          PS    State Govt.
# 1         SSS    State Govt.

# %%
# Write the sql query 
sql = """ 
SELECT *
FROM school_details
LIMIT 3;
"""
# execute the sql query
pd.read_sql_query(sql, con=engine)
# Out:
# 2023-02-19 13:26:35,621 INFO sqlalchemy.engine.Engine
# SELECT *
# FROM school_details
# LIMIT 3;
#
# 2023-02-19 13:26:35,622 INFO sqlalchemy.engine.Engine [raw sql] ()
#    index DistrictName EstablishmentCode  \
# 0      0         East             S0169
# 1      1         East             S0099
# 2      2         East             S0848
#
#                                    EstablishmentName   BRCName  \
# 0               BUDANG GOVERNMENT PRIMARY SCHOOL (E)  Duga Brc
# 1  CENTRAL PENDAM GOVERNMENT SENIOR SECONDARY SCHOOL  Duga Brc
# 2              CENTRAL POINT ACADEMY, CENTRAL PENDAM  Duga Brc
#
#                                              CRCName SchoolLevel  \
# 0  Central Pendam Government Senior Secondary School          PS
# 1  Central Pendam Government Senior Secondary School         SSS
# 2  Central Pendam Government Senior Secondary School          SS
#
#       ManagementName            LocalityHabitation SubdivisionName  ...  \
# 0        State Govt.                        BUDANG         Gangtok  ...
# 1        State Govt.                CENTRAL PENDAM         Gangtok  ...
# 2  Private (Unaided)  UPPER BHURUNG CENTRAL PENDAM         Gangtok  ...
#
#      EstablishedDate DistrictHQDistance (in Km) CRCDistance (in Km)  \
# 0              28126                       58.0                 8.0
# 1              15342                       50.0                 0.0
# 2  37257.38680555556                       49.0                 1.5
#
#   BACDistance (in Km) IsRecognized           RecognizedBy ContactPersonName  \
# 0                16.0   Recognized                   HRDD              None
# 1                 6.0   Recognized                   HRDD              None
# 2                 6.0   Recognized  HRDD, GOVT. OF SIKKIM              None
#
#   LowestClass HighestClass BoardName
# 0     Class 1      Class 5      None
# 1     Class 1     Class 12  C.B.S.E.
# 2     Class 1     Class 10  C.B.S.E.
#
# [3 rows x 31 columns]

# %%
sql = """
SELECT WardName, PostOfficeName
FROM school_details
LIMIT 3;
"""
pd.read_sql_query(sql, con=engine)
# Out:
# 2023-02-19 13:27:48,131 INFO sqlalchemy.engine.Engine
# SELECT WardName, PostOfficeName
# FROM school_details
# LIMIT 3;
#
# 2023-02-19 13:27:48,132 INFO sqlalchemy.engine.Engine [raw sql] ()
#      WardName PostOfficeName
# 0      Sajong   Upper Pendam
# 1  Karmithang   Upper Pendam
# 2      Burung   Upper Pendam

# %%
# Write the SQL query
sql = """
SELECT `CRCDistance (in Km)`
FROM school_details
"""

pd.read_sql_query(sql, engine)
# Out:
# 2023-02-19 13:29:14,430 INFO sqlalchemy.engine.Engine
# SELECT `CRCDistance (in Km)`
# FROM school_details
#
# 2023-02-19 13:29:14,431 INFO sqlalchemy.engine.Engine [raw sql] ()
#       CRCDistance (in Km)
# 0                     8.0
# 1                     0.0
# 2                     1.5
# 3                     6.0
# 4                     0.0
# ...                   ...
# 1244                  4.0
# 1245                  2.0
# 1246                  0.0
# 1247                  3.0
# 1248                  7.0
#
# [1249 rows x 1 columns]

# %% [markdown]
# # WHERE

# %%
# Write the SQL Query 
sql = """ 
SELECT EstablishmentName, CRCName, `CRCDistance (in Km)`
FROM school_details
WHERE `CRCDistance (in Km)` > 5;
"""
# Execute the query
pd.read_sql_query(sql, con=engine)
# Out:
# 2023-02-19 13:34:39,716 INFO sqlalchemy.engine.Engine
# SELECT EstablishmentName, CRCName, `CRCDistance (in Km)`
# FROM school_details
# WHERE `CRCDistance (in Km)` > 5;
#
# 2023-02-19 13:34:39,717 INFO sqlalchemy.engine.Engine [raw sql] ()
#                                  EstablishmentName  \
# 0             BUDANG GOVERNMENT PRIMARY SCHOOL (E)
# 1    CHEURIBOTEY GOVERNMENT JUNIOR HIGH SCHOOL (E)
# 2              NEW GARDEN BOARDING SCHOOL (SAJONG)
# 3               PACHAK GOVERNMENT SECONDARY SCHOOL
# 4                 PADMA KUMARI PUBLIC SCHOOL, DUGA
# ..                                             ...
# 352       NAMBUMANGTHANG GOVERNMENT PRIMARY SCHOOL
# 353             NERDHANG GOVERNMENT PRIMARY SCHOOL
# 354               RANGIT GOVERNMENT PRIMARY SCHOOL
# 355           THANGCHUNG GOVERNMENT PRIMARY SCHOOL
# 356                TSONG GOVERNMENT PRIMARY SCHOOL
#
#                                                CRCName  CRCDistance (in Km)
# 0    Central Pendam Government Senior Secondary School                  8.0
# 1    Central Pendam Government Senior Secondary School                  6.0
# 2    Central Pendam Government Senior Secondary School                  7.0
# 3    Central Pendam Government Senior Secondary School                  6.0
# 4    Central Pendam Government Senior Secondary School                200.0
# ..                                                 ...                  ...
# 352       Tashiding Government Senior Secondary School                 13.0
# 353       Tashiding Government Senior Secondary School                 35.0
# 354       Tashiding Government Senior Secondary School                 29.0
# 355       Tashiding Government Senior Secondary School                  6.0
# 356                 Yuksom Government Secondary School                  7.0
#
# [357 rows x 3 columns]

# %%
sql = """ 
SELECT EstablishmentName
FROM school_details
WHERE SchoolLevel = 'PS';
"""

pd.read_sql_query(sql, con=engine)
# Out:
# 2023-02-19 13:35:44,716 INFO sqlalchemy.engine.Engine
# SELECT EstablishmentName
# FROM school_details
# WHERE SchoolLevel = 'PS';
#
# 2023-02-19 13:35:44,717 INFO sqlalchemy.engine.Engine [raw sql] ()
#                              EstablishmentName
# 0         BUDANG GOVERNMENT PRIMARY SCHOOL (E)
# 1             EASWARAMMA SAI GURUKOOL ACCADEMY
# 2          ETERNAL ENGLISH SCHOOL, WEST PENDAM
# 3         KHANI GOAN GOVERNMENT PRIMARY SCHOOL
# 4          NEW GARDEN BOARDING SCHOOL (SAJONG)
# ..                                         ...
# 630       MANGSABONG GOVERNMENT PRIMARY SCHOOL
# 631  MANGTABONG GOVERNMENT PRIMARY SCHOOL(SSA)
# 632      NEW HORIZON ACADEMY, LASSO(TASHIDING)
# 633    TINGTING GAON GOVERNMENT PRIMARY SCHOOL
# 634            TSONG GOVERNMENT PRIMARY SCHOOL
#
# [635 rows x 1 columns]

# %% [markdown]
# # Wildcards (%) and LIKE

# %%
sql = """
SELECT EstablishmentName, PostofficeName
FROM school_details
WHERE EstablishmentName LIKE 'New%';
"""

pd.read_sql_query(sql, con=engine)
# Out:
# 2023-02-19 13:41:01,773 INFO sqlalchemy.engine.Engine
# SELECT EstablishmentName, PostofficeName
# FROM school_details
# WHERE EstablishmentName LIKE 'New%';
#
# 2023-02-19 13:41:01,773 INFO sqlalchemy.engine.Engine [raw sql] ()
#                             EstablishmentName PostOfficeName
# 0         NEW GARDEN BOARDING SCHOOL (SAJONG)   Upper Pendam
# 1                         NEW HORIZON ACADEMY         Rongpo
# 2                NEW VISION ACADEMY, MAJHITAR       Majhitar
# 3           NEW VISION ACADEMY, CHOTA SINGTAM  Assam Lingzey
# 4         NEW GARDEN BOARDING SCHOOL, SINGTAM        Singtam
# 5                 NEW BUDS ACADEMY, JORETHANG     Naya Bazar
# 6              NEW LIGHT ACADEMY, ASSANGTHANG    Assangthang
# 7                    NEW LIGHT ACADEMY NAMCHI         Namchi
# 8                 NEW STEPS ACADEMY, NAMTHANG       Namthang
# 9   NEW RAYS ACADEMY DEYTHANG BUSTY S. SIKKIM       Ravangla
# 10                    NEW HOPE ACADEMY, SIKIP            Vok
# 11     NEW LIGHT ENGLISH SCHOOL, MELLI PAYONG   Melli Bazaar
# 12                 NEW WISDOM ACADEMY, DENTAM         Dentam
# 13        NEW TULIPS KINDER GARTEN, GYALSHING        Pelling
# 14      NEW HORIZON ACADEMY, LASSO(TASHIDING)         Yuksom

# %%
sql = """
SELECT EstablishmentName
FROM school_details
WHERE EstablishmentName LIKE '%academy%'
"""
pd.read_sql_query(sql, con=engine)
# Out:
# 2023-02-19 13:42:29,579 INFO sqlalchemy.engine.Engine
# SELECT EstablishmentName
# FROM school_details
# WHERE EstablishmentName LIKE '%academy%'
#
# 2023-02-19 13:42:29,579 INFO sqlalchemy.engine.Engine [raw sql] ()
#                              EstablishmentName
# 0        CENTRAL POINT ACADEMY, CENTRAL PENDAM
# 1                        SUNRISE ACADEMY, DUGA
# 2                          NEW HORIZON ACADEMY
# 3                 NEW VISION ACADEMY, MAJHITAR
# 4            DE. NOBILE ACADEMY, ASSAM LINGZEY
# ..                                         ...
# 210       HIMALAYAN RADIANT ACADEMY, TASHIDING
# 211                  MARIGOLD ACADEMY, GANGYAP
# 212  MARIGOLD ACADEMY, POKHARI DARA, TASHIDING
# 213                LIFE VISION ACADEMY, YUKSAM
# 214      NEW HORIZON ACADEMY, LASSO(TASHIDING)
#
# [215 rows x 1 columns]

# %% [markdown]
# # Advanced WHERE

# %%
sql = """
SELECT EstablishmentName
FROM school_details
WHERE EstablishmentName LIKE 'new%' AND EstablishmentName LIKE '%academy%';
"""
pd.read_sql_query(sql, con=engine)
# Out:
# 2023-02-19 13:47:04,270 INFO sqlalchemy.engine.Engine
# SELECT EstablishmentName
# FROM school_details
# WHERE EstablishmentName LIKE 'new%' AND EstablishmentName LIKE '%academy%';
#
# 2023-02-19 13:47:04,270 INFO sqlalchemy.engine.Engine [raw sql] ()
#                             EstablishmentName
# 0                         NEW HORIZON ACADEMY
# 1                NEW VISION ACADEMY, MAJHITAR
# 2           NEW VISION ACADEMY, CHOTA SINGTAM
# 3                 NEW BUDS ACADEMY, JORETHANG
# 4              NEW LIGHT ACADEMY, ASSANGTHANG
# 5                    NEW LIGHT ACADEMY NAMCHI
# 6                 NEW STEPS ACADEMY, NAMTHANG
# 7   NEW RAYS ACADEMY DEYTHANG BUSTY S. SIKKIM
# 8                     NEW HOPE ACADEMY, SIKIP
# 9                  NEW WISDOM ACADEMY, DENTAM
# 10      NEW HORIZON ACADEMY, LASSO(TASHIDING)

# %%
sql = """
SELECT EstablishmentName
FROM school_details
WHERE EstablishmentName LIKE 'new%' AND `CRCDistance (in Km)` > 5;
"""
pd.read_sql_query(sql, engine)
# Out:
# 2023-02-19 13:48:39,418 INFO sqlalchemy.engine.Engine
# SELECT EstablishmentName
# FROM school_details
# WHERE EstablishmentName LIKE 'new%' AND `CRCDistance (in Km)` > 5;
#
# 2023-02-19 13:48:39,418 INFO sqlalchemy.engine.Engine [raw sql] ()
#                            EstablishmentName
# 0        NEW GARDEN BOARDING SCHOOL (SAJONG)
# 1               NEW VISION ACADEMY, MAJHITAR
# 2          NEW VISION ACADEMY, CHOTA SINGTAM
# 3  NEW RAYS ACADEMY DEYTHANG BUSTY S. SIKKIM
# 4                    NEW HOPE ACADEMY, SIKIP

# %%
sql = """
SELECT EstablishmentName
FROM school_details
WHERE EstablishmentName LIKE 'new%' AND EstablishmentName LIKE '%academy%' AND `CRCDistance (in Km)` > 5;
"""
pd.read_sql_query(sql, engine)
# Out:
# 2023-02-19 13:50:26,347 INFO sqlalchemy.engine.Engine
# SELECT EstablishmentName
# FROM school_details
# WHERE EstablishmentName LIKE 'new%' AND EstablishmentName LIKE '%academy%' AND `CRCDistance (in Km)` > 5;
#
# 2023-02-19 13:50:26,347 INFO sqlalchemy.engine.Engine [raw sql] ()
#                            EstablishmentName
# 0               NEW VISION ACADEMY, MAJHITAR
# 1          NEW VISION ACADEMY, CHOTA SINGTAM
# 2  NEW RAYS ACADEMY DEYTHANG BUSTY S. SIKKIM
# 3                    NEW HOPE ACADEMY, SIKIP

# %% [markdown]
# # ORDER BY and LIMIT

# %%
sql = """
SELECT EstablishmentName, `CRCDistance (in Km)`, CRCName 
FROM school_details
ORDER BY `CRCDistance (in Km)` DESC;
"""
pd.read_sql_query(sql, con=engine)
# Out:
# 2023-02-19 13:57:24,792 INFO sqlalchemy.engine.Engine
# SELECT EstablishmentName, `CRCDistance (in Km)`, CRCName
# FROM school_details
# ORDER BY `CRCDistance (in Km)` DESC;
#
# 2023-02-19 13:57:24,792 INFO sqlalchemy.engine.Engine [raw sql] ()
#                                  EstablishmentName  CRCDistance (in Km)  \
# 0                      MT. PANDIM ACADEMY, KEWZING                300.0
# 1                 PADMA KUMARI PUBLIC SCHOOL, DUGA                200.0
# 2            PLAY AND LEARN PRIMARY SCHOOL, MANGAN                200.0
# 3                   SARASWATI VIDYALAYA, GYALSHING                120.0
# 4     CHUJACHEN GOVERNMENT SENIOR SECONDARY SCHOOL                 76.0
# ...                                            ...                  ...
# 1244             HIMALAYAN BOARDING SCHOOL, YUKSAM                  0.0
# 1245         NEW HORIZON ACADEMY, LASSO(TASHIDING)                  0.0
# 1246                        MANJUSRI PUBLIC SCHOOL                  NaN
# 1247                     DEEP JYOTI ACCADEMY ROLEP                  NaN
# 1248                             UNIVERSAL ACADEMY                  NaN
#
#                                                 CRCName
# 0            Kewzing Government Senior Secondary School
# 1     Central Pendam Government Senior Secondary School
# 2             Mangan Government Senior Secondary School
# 3                     Gyalshing senior secondary school
# 4          Chujachen Government Senior Secondary School
# ...                                                 ...
# 1244                 Yuksom Government Secondary School
# 1245                 Yuksom Government Secondary School
# 1246   Tashi Namgyal Government Senior Secondary School
# 1247       Chujachen Government Senior Secondary School
# 1248                    Ben Government Secondary School
#
# [1249 rows x 3 columns]

# %%
sql = """
SELECT EstablishmentName, `CRCDistance (in Km)`, CRCName FROM school_details
ORDER BY `CRCDistance (in Km)` DESC
LIMIT 1;
"""
pd.read_sql_query(sql, con=engine)
# Out:
# 2023-02-19 13:58:47,418 INFO sqlalchemy.engine.Engine
# SELECT EstablishmentName, `CRCDistance (in Km)`, CRCName FROM school_details
# ORDER BY `CRCDistance (in Km)` DESC
# LIMIT 1;
#
# 2023-02-19 13:58:47,418 INFO sqlalchemy.engine.Engine [raw sql] ()
#              EstablishmentName  CRCDistance (in Km)  \
# 0  MT. PANDIM ACADEMY, KEWZING                300.0
#
#                                       CRCName
# 0  Kewzing Government Senior Secondary School

# %%
sql = """
SELECT EstablishmentName
FROM school_details
WHERE EstablishmentName LIKE '%government%'
LIMIT 10;
"""
pd.read_sql_query(sql, con=engine)
# Out:
# 2023-02-19 14:00:47,268 INFO sqlalchemy.engine.Engine
# SELECT EstablishmentName
# FROM school_details
# WHERE EstablishmentName LIKE '%government%'
# LIMIT 10;
#
# 2023-02-19 14:00:47,268 INFO sqlalchemy.engine.Engine [raw sql] ()
#                                    EstablishmentName
# 0               BUDANG GOVERNMENT PRIMARY SCHOOL (E)
# 1  CENTRAL PENDAM GOVERNMENT SENIOR SECONDARY SCHOOL
# 2      CHEURIBOTEY GOVERNMENT JUNIOR HIGH SCHOOL (E)
# 3                   DUGA GOVERNMENT SECONDARY SCHOOL
# 4               KHANI GOAN GOVERNMENT PRIMARY SCHOOL
# 5               OKHARBOTEY GOVERNMENT PRIMARY SCHOOL
# 6                 PACHAK GOVERNMENT SECONDARY SCHOOL
# 7               SAJONG GOVERNMENT JUNIOR HIGH SCHOOL
# 8              SAKHU KHANI GOVERNMENT PRIMARY SCHOOL
# 9         SAMSING SUNTALEY GOVERNMENT PRIMARY SCHOOL

# %%
sql = """
SELECT EstablishmentName, CRCName
FROM school_details
ORDER BY CRCName, EstablishmentName
LIMIT 20;
"""
pd.read_sql_query(sql, con=engine)
# Out:
# 2023-02-19 14:01:55,123 INFO sqlalchemy.engine.Engine
# SELECT EstablishmentName, CRCName
# FROM school_details
# ORDER BY CRCName, EstablishmentName
# LIMIT 20;
#
# 2023-02-19 14:01:55,124 INFO sqlalchemy.engine.Engine [raw sql] ()
#                                    EstablishmentName  \
# 0             AHO-KISHAN GOVERNMENT SECONDARY SCHOOL
# 1             AHO-SHANTI GOVERNMENT SECONDARY SCHOOL
# 2              AHO-YANGTAM GOVERNMENT PRIMARY SCHOOL
# 3                     BAPTIST ENGLISH SCHOOL, NIMTAR
# 4                BASILAKHA GOVERNMENT PRIMARY SCHOOL
# 5             LITTLE ANGEL ENGLISH SCHOOL, UPPER AHO
# 6              LITTLE ANGEL PRIMARY SCHOOL, KADAMTAM
# 7           LOWER KADAMTAM GOVERNMENT PRIMARY SCHOOL
# 8            NAMCHEYBONG GOVERNMENT SECONDARY SCHOOL
# 9                                NIM VALLEY , NIMTAR
# 10              NIMTAR GOVERNMENT JUNIOR HIGH SCHOOL
# 11              SARASWATI SISHU VIDYALAYA, AHO-BUSTY
# 12               ST. JOHNS ENGLISH MEDIUM, BASILAKHA
# 13          UPPER KADAMTAM GOVERNMENT PRIMARY SCHOOL
# 14  ASSAM LINGZEY GOVERNMENT SENIOR SECONDARY SCHOOL
# 15          DARING LINGZEY GOVERNMENT PRIMARY SCHOOL
# 16                 DE. NOBILE ACADEMY, ASSAM LINGZEY
# 17           GAUCHARAN GOVERNMENT JUNIOR HIGH SCHOOL
# 18               LITTLE ANGEL ENGLISH SCHOOL, NANDOK
# 19        LOWER NANDOK GOVERNMENT JUNIOR HIGH SCHOOL
#
#                                              CRCName
# 0             Aho-Shanti Government Secondary School
# 1             Aho-Shanti Government Secondary School
# 2             Aho-Shanti Government Secondary School
# 3             Aho-Shanti Government Secondary School
# 4             Aho-Shanti Government Secondary School
# 5             Aho-Shanti Government Secondary School
# 6             Aho-Shanti Government Secondary School
# 7             Aho-Shanti Government Secondary School
# 8             Aho-Shanti Government Secondary School
# 9             Aho-Shanti Government Secondary School
# 10            Aho-Shanti Government Secondary School
# 11            Aho-Shanti Government Secondary School
# 12            Aho-Shanti Government Secondary School
# 13            Aho-Shanti Government Secondary School
# 14  Assam Lingzey Government Senior Secondary School
# 15  Assam Lingzey Government Senior Secondary School
# 16  Assam Lingzey Government Senior Secondary School
# 17  Assam Lingzey Government Senior Secondary School
# 18  Assam Lingzey Government Senior Secondary School
# 19  Assam Lingzey Government Senior Secondary School

# %% [markdown]
# # Practice

# %% [markdown]
# 1. Get the EstablishmentName, SchoolLevel, and Website columns from the school_details table.

# %%
sql = """
SELECT EstablishmentName, SchoolLevel, Website
FROM school_details
LIMIT 2;
"""
pd.read_sql_query(sql, con=engine)
# Out:
# 2023-02-19 14:10:42,646 INFO sqlalchemy.engine.Engine
# SELECT EstablishmentName, SchoolLevel, Website
# FROM school_details
# LIMIT 2;
#
# 2023-02-19 14:10:42,646 INFO sqlalchemy.engine.Engine [raw sql] ()
#                                    EstablishmentName SchoolLevel Website
# 0               BUDANG GOVERNMENT PRIMARY SCHOOL (E)          PS    None
# 1  CENTRAL PENDAM GOVERNMENT SENIOR SECONDARY SCHOOL         SSS    None

# %% [markdown]
# 2. Display the EstablishmentName and DistrictHQDistance (in Km) for schools where the DistrictHQDistance (in Km) is more than 100 Km. Don't forget to use backticks! (`)

# %%
sql = """
SELECT EstablishmentName, `DistrictHQDistance (in Km)`
From school_details
WHERE `DistrictHQDistance (in Km)` > 100
LIMIT 5;
"""
pd.read_sql_query(sql, engine)
# Out:
# 2023-02-19 14:12:58,947 INFO sqlalchemy.engine.Engine
# SELECT EstablishmentName, `DistrictHQDistance (in Km)`
# From school_details
# WHERE `DistrictHQDistance (in Km)` > 100
# LIMIT 5;
#
# 2023-02-19 14:12:58,948 INFO sqlalchemy.engine.Engine [raw sql] ()
#                     EstablishmentName  DistrictHQDistance (in Km)
# 0  DODACHEN GOVERNMENT PRIMARY SCHOOL                       150.0
# 1   DEOLING GOVERNMENT PRIMARY SCHOOL                       107.0
# 2       PEMA TSEL ACADEMY(PHADAMCHEN)                       110.0
# 3    ZULUCK GOVERNMENT PRIMARY SCHOOL                       120.0
# 4   BHARENG GOVERNMENT PRIMARY SCHOOL                       150.0

# %% [markdown]
# 3. Display the EstablishmentName, SchoolLevel, DistrictHQDistance (in Km) for schools where the school level is "JHS."

# %%
sql = """
SELECT EstablishmentName, SchoolLevel, `DistrictHQDistance (in Km)`
FROM school_details
WHERE SchoolLevel = 'JHS'
LIMIT 5;
"""
pd.read_sql_query(sql, con=engine)
# Out:
# 2023-02-19 14:15:14,267 INFO sqlalchemy.engine.Engine
# SELECT EstablishmentName, SchoolLevel, `DistrictHQDistance (in Km)`
# FROM school_details
# WHERE SchoolLevel = 'JHS'
# LIMIT 5;
#
# 2023-02-19 14:15:14,267 INFO sqlalchemy.engine.Engine [raw sql] ()
#                                EstablishmentName SchoolLevel  \
# 0  CHEURIBOTEY GOVERNMENT JUNIOR HIGH SCHOOL (E)         JHS
# 1               PADMA KUMARI PUBLIC SCHOOL, DUGA         JHS
# 2           SAJONG GOVERNMENT JUNIOR HIGH SCHOOL         JHS
# 3      SINGLEYBONG GOVERNMENT JUNIOR HIGH SCHOOL         JHS
# 4                          SUNRISE ACADEMY, DUGA         JHS
#
#    DistrictHQDistance (in Km)
# 0                        60.0
# 1                        48.0
# 2                        57.0
# 3                        38.0
# 4                        47.0

# %% [markdown]
# 4. Display the EstablishmentName, SchoolLevel, DistrictHQDistance (in Km) for schools where the name of the school contains the words "JUNIOR HIGH."

# %%
sql = """
SELECT EstablishmentName, SchoolLevel, `DistrictHQDistance (in Km)`
FROM school_details
WHERE EstablishmentName LIKE '%JUNIOR HIGH%'
"""

pd.read_sql_query(sql, con=engine)
# Out:
# 2023-02-19 15:25:18,321 INFO sqlalchemy.engine.Engine
# SELECT EstablishmentName, SchoolLevel, `DistrictHQDistance (in Km)`
# FROM school_details
# WHERE EstablishmentName LIKE '%JUNIOR HIGH%'
#
# 2023-02-19 15:25:18,321 INFO sqlalchemy.engine.Engine [raw sql] ()
#                                   EstablishmentName SchoolLevel  \
# 0     CHEURIBOTEY GOVERNMENT JUNIOR HIGH SCHOOL (E)         JHS
# 1              SAJONG GOVERNMENT JUNIOR HIGH SCHOOL         JHS
# 2         SINGLEYBONG GOVERNMENT JUNIOR HIGH SCHOOL         JHS
# 3             BORDANG GOVERNMENT JUNIOR HIGH SCHOOL         JHS
# 4        RANGPO BAZAR GOVERNMENT JUNIOR HIGH SCHOOL         JHS
# ..                                              ...         ...
# 179           TAMATAM GOVERNMENT JUNIOR HIGH SCHOOL         JHS
# 180   UPPER GERETHANG GOVERNMENT JUNIOR HIGH SCHOOL         JHS
# 181        DARAPTHANG GOVERNMENT JUNIOR HIGH SCHOOL         JHS
# 182  MIDDLE CHONGRANG GOVERNMENT JUNIOR HIGH SCHOOL         JHS
# 183          TIMBRONG GOVERNMENT JUNIOR HIGH SCHOOL         JHS
#
#      DistrictHQDistance (in Km)
# 0                          60.0
# 1                          57.0
# 2                          38.0
# 3                          33.0
# 4                          47.0
# ..                          ...
# 179                        55.0
# 180                        60.0
# 181                        28.0
# 182                        60.0
# 183                        32.0
#
# [184 rows x 3 columns]

# %% [markdown]
# 5. Display the EstablishmentName, SchoolLevel, DistrictHQDistance (in Km) for schools where the name of the school starts with the letter "C." Sort the results alphabetically by school name and limit the results of the query to 10 rows.

# %%
sql = """
SELECT EstablishmentName, SchoolLevel, `DistrictHQDistance (in Km)`
FROM school_details
WHERE EstablishmentName LIKE 'c%'
ORDER BY EstablishmentName
LIMIT 20;
"""

pd.read_sql_query(sql, con=engine)
# Out:
# 2023-02-19 15:31:17,324 INFO sqlalchemy.engine.Engine
# SELECT EstablishmentName, SchoolLevel, `DistrictHQDistance (in Km)`
# FROM school_details
# WHERE EstablishmentName LIKE 'c%'
# ORDER BY EstablishmentName
# LIMIT 20;
#
# 2023-02-19 15:31:17,324 INFO sqlalchemy.engine.Engine [raw sql] ()
#                                     EstablishmentName SchoolLevel  \
# 0         C.M.RAI GOVERNMENT SECONDARY SCHOOL (OMCHU)          SS
# 1                             CANAAN SCHOOL, RANIPOOL         JHS
# 2                         CANARY BIRD ACADEMY, KARTOK          PS
# 3                 CAROL ACADEMY, YANGSUM UPPER BERFOK         JHS
# 4             CENTRAL MARTAM GOVERNMENT JUNIOR SCHOOL         JHS
# 5             CENTRAL PATUK GOVERNMENT PRIMARY SCHOOL          PS
# 6   CENTRAL PENDAM GOVERNMENT SENIOR SECONDARY SCHOOL         SSS
# 7               CENTRAL POINT ACADEMY, CENTRAL PENDAM          SS
# 8               CENTRAL SCHOOL FOR TIBETAN , RAVANGLA         JHS
# 9          CHAKUNG GOVERNMENT SENIOR SECONDARY SCHOOL         SSS
# 10         CHALLAMTHANG GOVERNMENT JUNIOR HIGH SCHOOL         JHS
# 11                CHANDANEY GOVERNMENT PRIMARY SCHOOL          PS
# 12  CHANDRA MAN RAI GOVERNMENT SECONDARY SCHOOL (J...          SS
# 13                  CHANGEY GOVERNMENT PRIMARY SCHOOL          PS
# 14             CHANGEYLAKHA GOVERNMENT PRIMARY SCHOOL          PS
# 15                   CHATEN GOVERNMENT PRIMARY SCHOOL          PS
# 16      CHATURSINGH RAI GOVERNMENT JUNIOR HIGH SCHOOL         JHS
# 17                  CHAWANG GOVERNMENT PRIMARY SCHOOL          PS
# 18             CHEMCHEY GOVERNMENT JUNIOR HIGH SCHOOL         JHS
# 19      CHEURIBOTEY GOVERNMENT JUNIOR HIGH SCHOOL (E)         JHS
#
#     DistrictHQDistance (in Km)
# 0                         26.0
# 1                          0.0
# 2                         38.0
# 3                         50.0
# 4                         50.0
# 5                         48.0
# 6                         50.0
# 7                         49.0
# 8                         26.0
# 9                         55.0
# 10                        60.0
# 11                        70.0
# 12                        38.0
# 13                        21.0
# 14                        77.0
# 15                        56.0
# 16                         1.0
# 17                        37.0
# 18                        16.0
# 19                        60.0

# %% [markdown]
# 6. Display the names of schools in urban areas. Sort the results in reverse alphabetical order.

# %%
school_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1249 entries, 0 to 1248
# Data columns (total 30 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   DistrictName                1249 non-null   object
#  1   EstablishmentCode           1249 non-null   object
#  2   EstablishmentName           1249 non-null   object
#  3   BRCName                     1249 non-null   object
#  4   CRCName                     1249 non-null   object
#  5   SchoolLevel                 1246 non-null   object
#  6   ManagementName              1246 non-null   object
#  7   LocalityHabitation          1221 non-null   object
#  8   SubdivisionName             1241 non-null   object
#  9   ConstituencyName            1249 non-null   object
#  10  RevenueBlockName            1249 non-null   object
#  11  CivicBodyName               1249 non-null   object
#  12  WardName                    1249 non-null   object
#  13  PostOfficeName              1249 non-null   object
#  14  PhoneNo                     794 non-null    object
#  15  FaxNo                       20 non-null     object
#  16  EmailID                     182 non-null    object
#  17  Website                     24 non-null     object
#  18  LocatedInRuralOrUrban       1249 non-null   object
#  19  DiseCode                    439 non-null    object
#  20  EstablishedDate             1230 non-null   object
#  21  DistrictHQDistance (in Km)  1246 non-null   float64
#  22  CRCDistance (in Km)         1246 non-null   float64
#  23  BACDistance (in Km)         1246 non-null   float64
#  24  IsRecognized                1246 non-null   object
#  25  RecognizedBy                1004 non-null   object
#  26  ContactPersonName           0 non-null      float64
#  27  LowestClass                 1246 non-null   object
#  28  HighestClass                1246 non-null   object
#  29  BoardName                   784 non-null    object
# dtypes: float64(4), object(26)
# memory usage: 292.9+ KB

# %%
sql = """
SELECT EstablishmentName, LocatedInRuralOrUrban
FROM school_details
WHERE LocatedInRuralOrUrban LIKE '%urban%'
ORDER BY EstablishmentName DESC
LIMIT 10;
"""

pd.read_sql_query(sql, engine)
# Out:
# 2023-02-19 15:35:56,615 INFO sqlalchemy.engine.Engine
# SELECT EstablishmentName, LocatedInRuralOrUrban
# FROM school_details
# WHERE LocatedInRuralOrUrban LIKE '%urban%'
# ORDER BY EstablishmentName DESC
# LIMIT 10;
#
# 2023-02-19 15:35:56,616 INFO sqlalchemy.engine.Engine [raw sql] ()
#                             EstablishmentName LocatedInRuralOrUrban
# 0            ZULUCK GOVERNMENT PRIMARY SCHOOL            Urban Area
# 1            ZOOM GOVERNMENT SECONDARY SCHOOL            Urban Area
# 2       ZITLANG GOVERNMENT JUNIOR HIGH SCHOOL            Urban Area
# 3            ZINGLA GOVERNMENT PRIMARY SCHOOL            Urban Area
# 4                        ZENITH PUBLIC SCHOOL            Urban Area
# 5          ZEEL GOVERNMENT JUNIOR HIGH SCHOOL            Urban Area
# 6           YANGTEY GOVERNMENT PRIMARY SCHOOL            Urban Area
# 7         YANGSUM GOVERNMENT SECONDARY SCHOOL            Urban Area
# 8  YANGANG GOVERNMENT SENIOR SECONDARY SCHOOL            Urban Area
# 9             YALLI GOVERNMENT PRIMARY SCHOOL            Urban Area

# %% [markdown]
# # Aggregates and DISTINCT

# %%
sql = """
SELECT AVG(`CRCDistance (in Km)`)
FROM school_details
"""
pd.read_sql_query(sql, con=engine)
# Out:
# 2023-02-19 15:38:23,582 INFO sqlalchemy.engine.Engine
# SELECT AVG(`CRCDistance (in Km)`)
# FROM school_details
#
# 2023-02-19 15:38:23,583 INFO sqlalchemy.engine.Engine [raw sql] ()
#    AVG(`CRCDistance (in Km)`)
# 0                    5.433028

# %%
sql = """
SELECT MAX(`DistrictHQDistance (in Km)`)
FROM school_details
"""
pd.read_sql_query(sql, con=engine)
# Out:
# 2023-02-19 15:39:57,475 INFO sqlalchemy.engine.Engine
# SELECT MAX(`DistrictHQDistance (in Km)`)
# FROM school_details
#
# 2023-02-19 15:39:57,475 INFO sqlalchemy.engine.Engine [raw sql] ()
#    MAX(`DistrictHQDistance (in Km)`)
# 0                              170.0

# %%
sql = """
SELECT DISTINCT LocatedInRuralOrUrban
FROM school_details

"""
pd.read_sql_query(sql, con=engine)
# Out:
# 2023-02-19 15:40:43,765 INFO sqlalchemy.engine.Engine
# SELECT DISTINCT LocatedInRuralOrUrban
# FROM school_details
#
#
# 2023-02-19 15:40:43,766 INFO sqlalchemy.engine.Engine [raw sql] ()
#   LocatedInRuralOrUrban
# 0            Urban Area
# 1            Rural Area
